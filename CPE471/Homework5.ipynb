# %%
from sympy import *

# %%
#Some important equations

#Symbols
V_bi = Symbol('V_bi')
k = Symbol('k')
T = Symbol('T')
N_a = Symbol('N_a')
N_d = Symbol('N_d')
N_i = Symbol('N_i')

potBarEq = Eq(V_bi, k*T*ln(N_a*N_d/(N_i**2)))

#Symbols
e_s = Symbol('e_s')
q_e = Symbol('q_e')
W = Symbol('W')
V_R = Symbol('V_R')

layerWidthEq = Eq(W,( 2*e_s*(V_bi+V_R)/q_e*(N_a+N_d)/(N_a*N_d))**.5 )


E_max = Symbol('E_max')
maxEEq = Eq(E_max, 2*(V_bi+V_R)/W)


maxEEq2 = Eq(E_max, 2*(V_bi+V_R)/( ( 2*e_s*(V_bi+V_R)/q_e*(N_a+N_d)/(N_a*N_d))**.5 ))


#Symbols
C = Symbol('C')
A = Symbol('A')

capEq = Eq(C, e_s*A/W)

#Symbols
V_B = Symbol('V_B')
E_crit = Symbol('E_crit')
N_B = Symbol('N_B')

vBreakEq = Eq(V_B,e_s*E_crit**2/(q_e*N_B))

# %%
#Question 1 
#7.2 Calculate the built-in potential barrier, Voi, for Si, Ge, and GaAs pn junctions if they each have the following dopant concentrations at T = 300 K: (a) Na = 1014 cm-3 Na 1017 cm-3 (b) Na = 5 X 1016 Na = 5 X 1016 (c) Na= 1017 N= 1017

#Constants
k = 8.617E-5 #Boltzmann constant
T = 300 #Temperature in Kelvin

#a
N_a = 1e14 #Dopant concentration in cm^-3
N_d = 1e17 #Dopant concentration in cm^-3

#Silicon
N_i = 1.5e10 #Intrinsic carrier concentration in cm^-3

subbed = potBarEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, V_bi) #Solve for V_bi
print("The built-in potential barrier for a, Silicon is: ", sol[0], "V") #Print solution

#Germanium
N_i = 2.4e13 #Intrinsic carrier concentration in cm^-3

subbed = potBarEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, V_bi) #Solve for V_bi
print("The built-in potential barrier for a, Germanium is: ", sol[0], "V") #Print solution

#Gallium Arsenide
N_i = 1.79e6 #Intrinsic carrier concentration in cm^-3

subbed = potBarEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, V_bi) #Solve for V_bi
print("The built-in potential barrier for a, Gallium Arsenide is: ", sol[0], "V") #Print solution

#b
N_a = 5e16 #Dopant concentration in cm^-3   
N_d = 5e16 #Dopant concentration in cm^-3

#Silicon
N_i = 1.5e10 #Intrinsic carrier concentration in cm^-3

subbed = potBarEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, V_bi) #Solve for V_bi
print("The built-in potential barrier for b, Silicon is: ", sol[0], "V") #Print solution

#Germanium
N_i = 2.4e13 #Intrinsic carrier concentration in cm^-3

subbed = potBarEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, V_bi) #Solve for V_bi
print("The built-in potential barrier for b, Germanium is: ", sol[0], "V") #Print solution

#Gallium Arsenide
N_i = 1.79e6 #Intrinsic carrier concentration in cm^-3

subbed = potBarEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, V_bi) #Solve for V_bi
print("The built-in potential barrier for b, Gallium Arsenide is: ", sol[0], "V") #Print solution


#c
N_a = 1e17 #Dopant concentration in cm^-3
N_d = 1e17 #Dopant concentration in cm^-3

#Silicon
N_i = 1.5e10 #Intrinsic carrier concentration in cm^-3

subbed = potBarEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, V_bi) #Solve for V_bi
print("The built-in potential barrier for c, Silicon is: ", sol[0], "V") #Print solution

#Germanium
N_i = 2.4e13 #Intrinsic carrier concentration in cm^-3

subbed = potBarEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, V_bi) #Solve for V_bi
print("The built-in potential barrier for c, Germanium is: ", sol[0], "V") #Print solution

#Gallium Arsenide
N_i = 1.79e6 #Intrinsic carrier concentration in cm^-3

subbed = potBarEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, V_bi) #Solve for V_bi
print("The built-in potential barrier for c, Gallium Arsenide is: ", sol[0], "V") #Print solution
# Out:
# The built-in potential barrier for a, Silicon is:  0.633802042609471 V
# The built-in potential barrier for a, Germanium is:  0.252357151536274 V
# The built-in potential barrier for a, Gallium Arsenide is:  1.10085670556317 V
# The built-in potential barrier for b, Silicon is:  0.776537328797128 V
# The built-in potential barrier for b, Germanium is:  0.395092437723931 V
# The built-in potential barrier for b, Gallium Arsenide is:  1.24359199175083 V
# The built-in potential barrier for c, Silicon is:  0.812374424326439 V
# The built-in potential barrier for c, Germanium is:  0.430929533253241 V
# The built-in potential barrier for c, Gallium Arsenide is:  1.27942908728014 V

# %%
#Question 2
#7.10 Consider a uniformly doped silicon pn junction with doping concentrations Na = 2 X 1017 cm-3 and N. = 4 x 1016 cm-3. (a) Determine Voi at T = 300 K. (b) Determine the temperature at which Vi increases by 2 percent. (Trial and error may have to be used.)

#Constants
k = 8.617E-5 #Boltzmann constant
N_a = 2e17 #Dopant concentration in cm^-3
N_d = 4e16 #Dopant concentration in cm^-3
N_i = 1.5e10 #Intrinsic carrier concentration in cm^-3

#a
T = 300 #Temperature in Kelvin

subbed = potBarEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, "V_bi") #Solve for V_bi
print("The built-in potential barrier for a, Silicon is: ", sol[0], "V") #Print solution

#b
V_bi = sol[0]*1.02 #Increase built-in potential barrier by 2%
N_i = N_i * (1) #Intrinsic carrier concentration in cm^-3

subbed = potBarEq.subs([("k",k),("V_bi",V_bi),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, "T") #Solve for T
print("The temperature for b, Silicon is: ", sol[0], "K") #Print solution
# Out:
# The built-in potential barrier for a, Silicon is:  0.806605940381415 V
# The temperature for b, Silicon is:  306.000000000000 K

# %%
#Question 3
#7.16 An abrupt silicon pn junction at T = 300 K has impurity doping concentrations of Na = 5 × 1016 cm-3 and Na = 1015 cm-3. Calculate (a) Vois (b) W at (1) VR = 0 and (it) VR = 5 V, and (c) | Emax | at (i) VR = 0 and (it) VR = 5.

#Constants
k = 8.617E-5 #Boltzmann constant
N_a = 5e16 #Dopant concentration in cm^-3
N_d = 1e15 #Dopant concentration in cm^-3
N_i = 1.5e10 #Intrinsic carrier concentration in cm^-3
T = 300 #Temperature in Kelvin

#a
subbed = potBarEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, "V_bi") #Solve for V_bi
print("The built-in potential barrier for a, Silicon is: ", sol[0], "V") #Print solution

#b
V_R = 0 
q_e = 1.602E-19 #Charge of an electron in C
V_bi = sol[0] #Built-in potential barrier in V
e_s = 11.7*8.854E-14 #Relative permittivity of silicon in F/cm

subbed = layerWidthEq.subs([("q_e",q_e),("V_bi",V_bi),("e_s",e_s),("V_R",V_R)]) #Substitute in values
subbed = subbed.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, "W") #Solve for W
print("The layer width for b, Silicon is: ", sol[0], "cm") #Print solution
W_0 = sol[0] #Layer width in cm

#c
V_R = 5 #Voltage in V

subbed = layerWidthEq.subs([("q_e",q_e),("V_bi",V_bi),("e_s",e_s),("V_R",V_R)]) #Substitute in values
subbed = subbed.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, "W") #Solve for W
print("The layer width for b, Silicon is: ", sol[0], "cm") #Print solution
W_5 = sol[0] #Layer width at 5V in cm

#d 
V_R = 0 #Voltage in V
E_max = 2*(V_bi + V_R)/W_0 #Maximum electric field
print("The maximum electric field for d, Silicon is: ", E_max, "V/cm") #Print solution

#e
V_R = 5 #Voltage in V
E_max = 2*(V_bi + V_R)/W_5 #Maximum electric field
print("The maximum electric field for d, Silicon is: ", E_max, "V/cm") #Print solution
# Out:
# The built-in potential barrier for a, Silicon is:  0.675407622083805 V
# The layer width for b, Silicon is:  9.43907629023332e-5 cm
# The layer width for b, Silicon is:  0.000273618241285155 cm
# The maximum electric field for d, Silicon is:  14310.8838474513 V/cm
# The maximum electric field for d, Silicon is:  41484.1320185894 V/cm

# %%
#Question 4
#7.20 (a) The peak electric field in a reverse-biased silicon pn junction is |Emax| = 3 X 10S V/cm. The doping concentrations are Na = 4 X 10'5 cm-3 and Na = 4 X 1017 cm-3. Find the magnitude of the reverse-biased voltage. (b) Repeat part (a) for Na = 4 × 101° cm-3 and N. = 4 X 10'7 cm-3. (c) Repeat part (a) for Na = N. = 4 X 1017 cm-3.

#Constants
k = 8.617E-5 #Boltzmann constant
N_a = 4e17 #Dopant concentration in cm^-3
N_d = 4e15 #Dopant concentration in cm^-3
N_i = 1.5e10 #Intrinsic carrier concentration in cm^-3

e_s = 11.7*8.854E-14 #Relative permittivity of silicon in F/cm
q_e = 1.602E-19 #Charge of an electron in C
E_max = 3e5 #Maximum electric field in V/cm

T = 300

#a
subbed = potBarEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, "V_bi") #Solve for V_bi
print("The built-in potential barrier for a, Silicon is: ", sol[0], "V") #Print solution
V_bi = sol[0] #Built-in potential barrier in V

subbed = maxEEq2.subs([("q_e",q_e),("V_bi",V_bi),("e_s",e_s),("E_max",E_max)]) #Substitute in values
subbed = subbed.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, "V_R") #Solve for V_R
print("The reverse-biased voltage for a, Silicon is: ", sol[0], "V") #Print solution

#b
N_a = 4e17 #Dopant concentration in cm^-3
N_d = 4e16 #Dopant concentration in cm^-3

subbed = potBarEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, "V_bi") #Solve for V_bi
print("The built-in potential barrier for b, Silicon is: ", sol[0], "V") #Print solution
V_bi = sol[0] #Built-in potential barrier in V

subbed = maxEEq2.subs([("q_e",q_e),("V_bi",V_bi),("e_s",e_s),("E_max",E_max)]) #Substitute in values
subbed = subbed.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, "V_R") #Solve for V_R
print("The reverse-biased voltage for b, Silicon is: ", sol[0], "V") #Print solution

#c
N_a = 4e17 #Dopant concentration in cm^-3
N_d = 4e17 #Dopant concentration in cm^-3

subbed = potBarEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, "V_bi") #Solve for V_bi
print("The built-in potential barrier for c, Silicon is: ", sol[0], "V") #Print solution
V_bi = sol[0] #Built-in potential barrier in V

subbed = maxEEq2.subs([("q_e",q_e),("V_bi",V_bi),("e_s",e_s),("E_max",E_max)]) #Substitute in values
subbed = subbed.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, "V_R") #Solve for V_R
print("The reverse-biased voltage for c, Silicon is: ", sol[0], "V") #Print solution
# Out:
# The built-in potential barrier for a, Silicon is:  0.765000360907081 V
# The reverse-biased voltage for a, Silicon is:  72.7095207065084 V
# The built-in potential barrier for b, Silicon is:  0.824524488146070 V
# The reverse-biased voltage for b, Silicon is:  7.17765107365170 V
# The built-in potential barrier for c, Silicon is:  0.884048615385059 V
# The reverse-biased voltage for c, Silicon is:  0.570892395850889 V

# %%
#Question 5
#7.30 A silicon pt junction has doping concentrations of N. = 2 X 10'7 cm-3 and Na 2 X 10'5 cm -3. The cross-sectional area is 10-5 cm?. Calculate (a) Voi and (b) the junc tion capacitance at (i) VR = 1 V, (li) VR = 3 V, and (ili) VR = 5 V. (c) Plot 1/C2 versus VR and show that the slope can be used to find Na and the intercept at the voltage axis yields Voie

#Constants
k = 8.617E-5 #Boltzmann constant
N_a = 2e17 #Dopant concentration in cm^-3
N_d = 2e15 #Dopant concentration in cm^-3
N_i = 1.5e10 #Intrinsic carrier concentration in cm^-3
e_s = 11.7*8.854E-14 #Relative permittivity of silicon in F/cm 
q_e = 1.602E-19 #Charge of an electron in C
A = 1e-5 #Area in cm^2
T = 300


#a
subbed = potBarEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
sol = solve(subbed, "V_bi") #Solve for V_bi
print("The built-in potential barrier for a, Silicon is: ", sol[0], "V") #Print solution
V_bi = sol[0] #Built-in potential barrier in V

#b
V_R = 1 #Reverse-biased voltage in V

#First calculate W 
subbed = layerWidthEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
subbed = subbed.subs([("V_bi",V_bi),("V_R",V_R)]) #Substitute in values
subbed = subbed.subs([("e_s",e_s),("q_e",q_e)]) #Substitute in values

sol = solve(subbed, "W") #Solve for W
print("The width of the depletion layer for b, Silicon is: ", sol[0], "cm") #Print solution
W = sol[0] #Width of the depletion layer in cm

#Now calculate C
subbed = capEq.subs([("e_s",e_s),("q_e",q_e)]) #Substitute in values
subbed = subbed.subs([("W",W),("A",A)]) #Substitute in values
sol = solve(subbed, "C") #Solve for C
print("The capacitance of the junction for b, Silicon is: ", sol[0], "F") #Print solution
C = sol[0] #Capacitance of the junction in F
print(1/C**2)

#ii
V_R = 3 #Reverse-biased voltage in V

#First calculate W
subbed = layerWidthEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
subbed = subbed.subs([("V_bi",V_bi),("V_R",V_R)]) #Substitute in values
subbed = subbed.subs([("e_s",e_s),("q_e",q_e)]) #Substitute in values
sol = solve(subbed, "W") #Solve for W
print("The width of the depletion layer for b, Silicon is: ", sol[0], "cm") #Print solution
W = sol[0] #Width of the depletion layer in cm

#Now calculate C
subbed = capEq.subs([("e_s",e_s),("q_e",q_e)]) #Substitute in values
subbed = subbed.subs([("W",W),("A",A)]) #Substitute in values
sol = solve(subbed, "C") #Solve for C
print("The capacitance of the junction for b, Silicon is: ", sol[0], "F") #Print solution
C = sol[0] #Capacitance of the junction in F
print(1/C**2)

#iii
V_R = 5 #Reverse-biased voltage in V

#First calculate W
subbed = layerWidthEq.subs([("k",k),("T",T),("N_i",N_i),("N_a",N_a),("N_d",N_d)]) #Substitute in values
subbed = subbed.subs([("V_bi",V_bi),("V_R",V_R)]) #Substitute in values
subbed = subbed.subs([("e_s",e_s),("q_e",q_e)]) #Substitute in values
sol = solve(subbed, "W") #Solve for W
print("The width of the depletion layer for b, Silicon is: ", sol[0], "cm") #Print solution
W = sol[0] #Width of the depletion layer in cm

#Now calculate C
subbed = capEq.subs([("e_s",e_s),("q_e",q_e)]) #Substitute in values
subbed = subbed.subs([("W",W),("A",A)]) #Substitute in values
sol = solve(subbed, "C") #Solve for C
print("The capacitance of the junction for b, Silicon is: ", sol[0], "F") #Print solution
C = sol[0] #Capacitance of the junction in F
print(1/C**2)
# Out:
# The built-in potential barrier for a, Silicon is:  0.729163265377771 V
# The width of the depletion layer for b, Silicon is:  0.000106269863093290 cm
# The capacitance of the junction for b, Silicon is:  9.74799411466833e-14 F
# 1.05237248196647e+26
# The width of the depletion layer for b, Silicon is:  0.000156062233998230 cm
# The capacitance of the junction for b, Silicon is:  6.63785192266150e-14 F
# 2.26957678307284e+26
# The width of the depletion layer for b, Silicon is:  0.000193436185754295 cm
# The capacitance of the junction for b, Silicon is:  5.35534753210982e-14 F
# 3.48678108417922e+26

# %%
#Question 6
#7.38 (a) A symmetrically doped silicon pn junction diode has doping concentrations of Na = Na = 2 X 101° cm-3. Assuming the critical electric field is Ecrit = 4 X 105 V/cm, determine the breakdown voltage. (b) Repeat part (a) if the doping concentrations are Na = Na 1 = 5 X 1015 cm-3.

#Constants
k = 8.617E-5 #Boltzmann constant
N_a = 2e17 #Dopant concentration in cm^-3
N_d = 2e17 #Dopant concentration in cm^-3
N_i = 1.5e10 #Intrinsic carrier concentration in cm^-3
e_s = 11.7*8.854E-14 #Relative permittivity of silicon in F/cm
q_e = 1.602E-19 #Charge of an electron in C

E_crit = 4e5 #Critical electric field in V/cm
N_b = 2e16 #Breakdown concentration in cm^-3
#a
subbed = vBreakEq.subs([("e_s",e_s),("E_crit",E_crit),("q_e",q_e),("N_B",N_b)]) #Substitute in values

sol = solve(subbed, "V_B") #Solve for V_break
print("The breakdown voltage for a, Silicon is: ", sol[0], "V") #Print solution

#b
N_a = 5e15 #Dopant concentration in cm^-3
N_d = 5e15 #Dopant concentration in cm^-3
N_b = 5e15 #Breakdown concentration in cm^-3
subbed = vBreakEq.subs([("e_s",e_s),("E_crit",E_crit),("q_e",q_e),("N_B",N_b)]) #Substitute in values
sol = solve(subbed, "V_B") #Solve for V_break
print("The breakdown voltage for b, Silicon is: ", sol[0], "V") #Print solution
# Out:
# The breakdown voltage for a, Silicon is:  51.7312359550562 V
# The breakdown voltage for b, Silicon is:  206.924943820225 V
