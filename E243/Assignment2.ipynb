# %%
import pandas as pd
from sympy import *
import matplotlib.pyplot as plt 
import numpy as np

# %%
# A classroom contains 8 students. A student committee of 3 (president, vice-president, and treasurer) must be selected. Harry Potter will serve only as president and only if either of his friends Ron Weasley or Hermione Granger serve as vice president; otherwise he leaves the group. The others (including Ron and Hermione) have no such restrictions. What is the probability that Ron or Hermione become the president of this group? Report answer to 3 decimal places.

#Given
n = 8

#Total number of scenarios when Ron is president
n1 = (n-1)*(n-2)

# %%
#f(x) = (x+1)(x-1)(x-2) and g(x) = 3f(x-2)
#State the coordinates of the points where teh graph g intercepts the x-axis

#Given
x = Symbol('x')
f = (x+1)*(x-1)*(x-2)
g = 3*f.subs(x,x-2)

#Find the coordinates of the points where g intercepts the x-axis

#Equations
eq1 = Eq(g,0)

#Solve for x
sol = solve(eq1,x)

#Graph g and x intercepts on the same graph
xLin = np.linspace(-5,5,100)
#Calculate y 
y = lambdify(x,g)
y = y(xLin)

plt.plot(xLin,y)

#Plot the x intercepts
for i in range(len(sol)):
    plt.plot(sol[i],0,'ro')
plt.show()


#Print the coordinates
print("The coordinates of the points where g intercepts the x-axis are: ",sol)
# Out:
# The coordinates of the points where g intercepts the x-axis are:  [1, 3, 4]

# %%
#Let f(x) = ( 2x**2 +3 )/75 and g(x) = |3x-4|/10
#Find the range of f and g 

#Given
x = Symbol('x')
f = (2*x**2 +3)/75
g = Abs(3*x-4)/10

#Plot f and g on the same graph between -5 and 5
xLin = np.linspace(-5,5,100)
#Calculate y
y = lambdify(x,f)
y = y(xLin)
plt.plot(xLin,y)

y = lambdify(x,g)
y = y(xLin)
plt.plot(xLAin,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [28], line 18
#      16 y = lambdify(x,g)
#      17 y = y(xLin)
# ---> 18 plt.plot(xLAin,y)
#
# NameError: name 'xLAin' is not defined

# %%
g
# Out:
# 3*(x - 4)*(x - 3)*(x - 1)

# %%
vector = [1/2,0]
